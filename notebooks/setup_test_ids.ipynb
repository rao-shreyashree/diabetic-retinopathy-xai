# %%
# Cell 1: mount Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Cell 2: clone repo
REPO_URL = "https://github.com/rao-shreyashree/diabetic-retinopathy-xai.git"
REPO_DIR = "/content/diabetic-retinopathy-xai"

import os
if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}
else:
    # !cd {REPO_DIR} && git pull
# Out:
# Cloning into '/content/diabetic-retinopathy-xai'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 20 (delta 5), reused 18 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 201.61 KiB | 3.30 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# Cell 3: run mask_loader.py against the Drive data path
DATA_ROOT = "/content/drive/MyDrive/Projects/diabetic retinopathy/diabetic-retinopathy-xai/data/IDRiD"

# %cd /content/diabetic-retinopathy-xai/utils
# !python mask_loader.py "{DATA_ROOT}" test
# Out:
# /content/diabetic-retinopathy-xai/utils
# Froze 27 image IDs -> test_image_ids.json
# ['IDRiD_55', 'IDRiD_56', 'IDRiD_57', 'IDRiD_58', 'IDRiD_59', 'IDRiD_60', 'IDRiD_61', 'IDRiD_62', 'IDRiD_63', 'IDRiD_64', 'IDRiD_65', 'IDRiD_66', 'IDRiD_67', 'IDRiD_68', 'IDRiD_69', 'IDRiD_70', 'IDRiD_71', 'IDRiD_72', 'IDRiD_73', 'IDRiD_74', 'IDRiD_75', 'IDRiD_76', 'IDRiD_77', 'IDRiD_78', 'IDRiD_79', 'IDRiD_80', 'IDRiD_81']

# %%
# Cell 4: sanity check + push the frozen list back so Tanvi and Shravani get it
# !cat test_image_ids.json | head -20
# Out:
# [
#   "IDRiD_55",
#   "IDRiD_56",
#   "IDRiD_57",
#   "IDRiD_58",
#   "IDRiD_59",
#   "IDRiD_60",
#   "IDRiD_61",
#   "IDRiD_62",
#   "IDRiD_63",
#   "IDRiD_64",
#   "IDRiD_65",
#   "IDRiD_66",
#   "IDRiD_67",
#   "IDRiD_68",
#   "IDRiD_69",
#   "IDRiD_70",
#   "IDRiD_71",
#   "IDRiD_72",
#   "IDRiD_73",

# %%
# !cp test_image_ids.json "/content/drive/MyDrive/Projects/diabetic retinopathy/diabetic-retinopathy-xai/test_image_ids.json"
print("done")
# Out:
# done
